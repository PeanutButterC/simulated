# %% [markdown]
# ### This notebook demonstrates loading and analyzing crowdsourced labels

# %%
import pandas as pd
import os
meta = pd.read_csv('../data/crowdsourcing_meta.csv', index_col='index')
meta.iloc[0]['url']
# Out:
# 'https://plunarlabcit.services.brown.edu/crowdsourcing/videos/0.mp4'

# %% [markdown]
# ### Meta
#
# The meta file contains a reference to all crowdsourcing queries, including the action label, video url, session id, start and end frame

# %%
meta = pd.read_csv('../research/crowdsourcing/meta.csv', index_col='index')
responses = pd.read_csv('../research/crowdsourcing/production_1/responses.csv', index_col='index')
responses
# Out:
#        meta_idx  batch_idx  action   type                    query  \
# index
# 0         19675       2197    turn   test   Is the object turning?
# 1         19676       2197    turn   test   Is the object turning?
# 2         19677       2197    turn   test   Is the object turning?
# 3         19678       2197    turn   test   Is the object turning?
# 4         19679       2197    turn   test   Is the object turning?
# ...         ...        ...     ...    ...                      ...
# 21595     33122        491  bounce  train  Does the object bounce?
# 21596     33123        491  bounce  train  Does the object bounce?
# 21597     33124        491  bounce  train  Does the object bounce?
# 21598     33125        491  bounce  train  Does the object bounce?
# 21599     33126        491  bounce  train  Does the object bounce?
#
#                                                      url response_1  \
# index
# 0      https://plunarlabcit.services.brown.edu/crowds...        yes
# ...
